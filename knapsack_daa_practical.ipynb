# %%
import time

n = int(input("Enter number of items: "))

weights = []
values = []

print("Enter weights:")
for i in range(n):
    weights.append(int(input(f"Weight of item {i + 1}: ")))

print("Enter values:")
for i in range(n):
    values.append(int(input(f"Value of item {i + 1}: ")))

capacity = int(input("Enter knapsack capacity: "))

start_time = time.perf_counter()

dp = [[0] * (capacity + 1) for _ in range(n + 1)]

for i in range(1, n + 1):
    for w in range(1, capacity + 1):

        if weights[i - 1] <= w:
            dp[i][w] = max(
                values[i - 1] + dp[i - 1][w - weights[i - 1]],
                dp[i - 1][w]
            )
        else:
            dp[i][w] = dp[i - 1][w]

end_time = time.perf_counter()

print("\nMaximum Profit/Value:", dp[n][capacity])
print("Execution Time:", end_time - start_time, "seconds")

print("\nTime Complexity: O(n × W)")
print("Space Complexity: O(n × W)")
# Out:
# Enter number of items: 4
# Enter weights:
# Weight of item 1: 2
# Weight of item 2: 3
# Weight of item 3: 4
# Weight of item 4: 5
# Enter values:
# Value of item 1: 3
# Value of item 2: 4
# Value of item 3: 5
# Value of item 4: 6
# Enter knapsack capacity: 5
#
# Maximum Profit/Value: 7
# Execution Time: 0.00038175999998202315 seconds
#
# Time Complexity: O(n × W)
# Space Complexity: O(n × W)
