# %%
import time

# Number of vertices
n = int(input("Enter number of vertices: "))

# Create graph
graph = [[] for _ in range(n)]

# Number of edges
e = int(input("Enter number of edges: "))

# Enter edges
print("Enter edges (u v):")
for i in range(e):
    u, v = map(int, input().split())
    graph[u].append(v)
    graph[v].append(u)   # Remove this line for directed graph

# Starting vertex
start = int(input("Enter starting vertex: "))

# BFS
visited = [False] * n
queue = [start]
visited[start] = True

bfs_result = []

start_time = time.perf_counter()

while queue:
    vertex = queue.pop(0)
    bfs_result.append(vertex)

    for neighbour in graph[vertex]:
        if not visited[neighbour]:
            visited[neighbour] = True
            queue.append(neighbour)

end_time = time.perf_counter()

print("BFS Traversal:", bfs_result)
print("Execution Time:", end_time - start_time, "seconds")
print("Time Complexity: O(V + E)")
# Out:
# Enter number of vertices: 5
# Enter number of edges: 5
# Enter edges (u v):
#  0 1
# 0    2
# 1   3
# 1   4
# 2    4
# Enter starting vertex: 0
# BFS Traversal: [0, 1, 2, 3, 4]
# Execution Time: 0.000182018000032258 seconds
# Time Complexity: O(V + E)

# %%
import time

# Number of vertices
n = int(input("Enter number of vertices: "))

# Create graph
graph = [[] for _ in range(n)]

# Number of edges
e = int(input("Enter number of edges: "))

# Enter edges
print("Enter edges (u v):")
for i in range(e):
    u, v = map(int, input().split())
    graph[u].append(v)
    graph[v].append(u)   # Remove this line for directed graph

# Starting vertex
start = int(input("Enter starting vertex: "))

visited = [False] * n
dfs_result = []

def dfs(vertex):
    visited[vertex] = True
    dfs_result.append(vertex)

    for neighbour in graph[vertex]:
        if not visited[neighbour]:
            dfs(neighbour)

start_time = time.perf_counter()

dfs(start)

end_time = time.perf_counter()

print("DFS Traversal:", dfs_result)
print("Execution Time:", end_time - start_time, "seconds")
print("Time Complexity: O(V + E)")
# Out:
# Enter number of vertices: 5
# Enter number of edges: 5
# Enter edges (u v):
# 0  1
# 0   2
# 1    3
# 1  4
# 2   4
# Enter starting vertex: 0
# DFS Traversal: [0, 1, 3, 4, 2]
# Execution Time: 0.00010253300001750176 seconds
# Time Complexity: O(V + E)
